# %%
from tensorflow.keras.layers import Dense, Embedding, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.datasets import imdb

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)

# %%
X_train = pad_sequences(X_train, maxlen=200)
X_test = pad_sequences(X_test, maxlen=200)

# %%
model = Sequential()

model.add(Embedding(input_dim=10000, output_dim=32, input_length=200))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 200, 32)           320000
#
#  flatten_3 (Flatten)         (None, 6400)              0
#
#  dense_4 (Dense)             (None, 32)                204832
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 524865 (2.00 MB)
# Trainable params: 524865 (2.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\chait\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\chait\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\chait\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 704/704 [==============================] - 5s 6ms/step - loss: 0.4070 - accuracy: 0.7970 - val_loss: 0.3014 - val_accuracy: 0.8816
# Epoch 2/10
# 704/704 [==============================] - 5s 7ms/step - loss: 0.1195 - accuracy: 0.9592 - val_loss: 0.3582 - val_accuracy: 0.8664
# Epoch 3/10
# 704/704 [==============================] - 7s 10ms/step - loss: 0.0165 - accuracy: 0.9971 - val_loss: 0.4601 - val_accuracy: 0.8652
# Epoch 4/10
# 704/704 [==============================] - 8s 11ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4895 - val_accuracy: 0.8716
# Epoch 5/10
# 704/704 [==============================] - 8s 11ms/step - loss: 5.5193e-04 - accuracy: 1.0000 - val_loss: 0.5208 - val_accuracy: 0.8724
# Epoch 6/10
# 704/704 [==============================] - 8s 11ms/step - loss: 2.6575e-04 - accuracy: 1.0000 - val_loss: 0.5463 - val_accuracy: 0.8748
# Epoch 7/10
# 704/704 [==============================] - 8s 11ms/step - loss: 1.5647e-04 - accuracy: 1.0000 - val_loss: 0.5709 - val_accuracy: 0.8740
# Epoch 8/10
# 704/704 [==============================] - 8s 11ms/step - loss: 9.6567e-05 - accuracy: 1.0000 - val_loss: 0.5936 - val_accuracy: 0.8744
# Epoch 9/10
# 704/704 [==============================] - 8s 11ms/step - loss: 6.0877e-05 - accuracy: 1.0000 - val_loss: 0.6147 - val_accuracy: 0.8756
# Epoch 10/10
# 704/704 [==============================] - 6s 9ms/step - loss: 3.9376e-05 - accuracy: 1.0000 - val_loss: 0.6388 - val_accuracy: 0.8728

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"{loss=}")
print(f"{accuracy=}")
# Out:
# 782/782 [==============================] - 3s 4ms/step - loss: 0.6622 - accuracy: 0.8645
# loss=0.6621677875518799
# accuracy=0.8645200133323669

# %%
new_data = X_test[:5]
model.predict(new_data)
# Out:
# 1/1 [==============================] - 0s 116ms/step
# array([[0.00176671],
#        [1.        ],
#        [0.05274209],
#        [0.758229  ],
#        [0.9999978 ]], dtype=float32)
